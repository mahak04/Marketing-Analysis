# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
df = pd.read_csv('ifood_df.csv')
df.head()
# Out:
#     Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  58138.0        0         0       58       635         88              546
# 1  46344.0        1         1       38        11          1                6
# 2  71613.0        0         0       26       426         49              127
# 3  26646.0        1         0       26        11          4               20
# 4  58293.0        1         0       94       173         43              118
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              172                88            88  ...                 0
# 1                2                 1             6  ...                 0
# 2              111                21            42  ...                 1
# 3               10                 3             5  ...                 1
# 4               46                27            15  ...                 0
#
# ...

# %% [markdown]
# #### Descriptive Statistics

# %%
df.shape
# Out:
# (2205, 39)

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2205.000000  2205.000000  2205.000000  2205.000000  2205.000000
# mean    51622.094785     0.442177     0.506576    49.009070   306.164626
# std     20713.063826     0.537132     0.544380    28.932111   337.493839
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35196.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51287.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68281.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2205.000000      2205.000000      2205.000000       2205.000000
# mean     26.403175       165.312018        37.756463         27.128345
# std      39.784484       217.784507        54.824635         41.130468
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2205 non-null   float64
#  1   Kidhome               2205 non-null   int64
#  2   Teenhome              2205 non-null   int64
#  3   Recency               2205 non-null   int64
#  4   MntWines              2205 non-null   int64
#  5   MntFruits             2205 non-null   int64
#  6   MntMeatProducts       2205 non-null   int64
#  7   MntFishProducts       2205 non-null   int64
#  8   MntSweetProducts      2205 non-null   int64
#  9   MntGoldProds          2205 non-null   int64
#  10  NumDealsPurchases     2205 non-null   int64
#  11  NumWebPurchases       2205 non-null   int64
#  12  NumCatalogPurchases   2205 non-null   int64
#  13  NumStorePurchases     2205 non-null   int64
#  14  NumWebVisitsMonth     2205 non-null   int64
# ...

# %% [markdown]
# There are no null values in the dataset. All are features are continuous in nature.

# %%
df.columns
# Out:
# Index(['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married',
#        'marital_Single', 'marital_Together', 'marital_Widow',
#        'education_2n Cycle', 'education_Basic', 'education_Graduation',
#        'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds',
#        'AcceptedCmpOverall'],
#       dtype='object')

# %%
df['Income'].describe()
# Out:
# count      2205.000000
# mean      51622.094785
# std       20713.063826
# min        1730.000000
# 25%       35196.000000
# 50%       51287.000000
# 75%       68281.000000
# max      113734.000000
# Name: Income, dtype: float64

# %%
d = df['Kidhome']
d.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
d = df.groupby('Kidhome')['Kidhome'].count()

# %%
d
# Out:
# Kidhome
# 0    1276
# 1     883
# 2      46
# Name: Kidhome, dtype: int64

# %%
plt.pie(d, labels = d.index, autopct = '%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = df.drop(['Z_CostContact', 'Z_Revenue'], axis = 1)

# %%
for i in df.columns:
    print(i, df[i].nunique(), '\n')
# Out:
# Income 1963
#
# Kidhome 3
#
# Teenhome 3
#
# Recency 100
#
# MntWines 775
#
# MntFruits 158
#
# MntMeatProducts 551
#
# MntFishProducts 182
#
# MntSweetProducts 176
#
# MntGoldProds 212
#
# NumDealsPurchases 15
#
# NumWebPurchases 15
#
# NumCatalogPurchases 13
#
# NumStorePurchases 14
#
# NumWebVisitsMonth 16
#
# AcceptedCmp3 2
#
# AcceptedCmp4 2
#
# AcceptedCmp5 2
#
# AcceptedCmp1 2
#
# AcceptedCmp2 2
#
# Complain 2
#
# Response 2
#
# Age 56
#
# Customer_Days 662
#
# marital_Divorced 2
#
# marital_Married 2
#
# marital_Single 2
#
# marital_Together 2
#
# marital_Widow 2
#
# education_2n Cycle 2
#
# education_Basic 2
#
# education_Graduation 2
#
# education_Master 2
#
# education_PhD 2
#
# MntTotal 897
#
# MntRegularProds 974
#
# AcceptedCmpOverall 5

# %%
for i in df.columns:
    print(i, df[i].unique(), '\n')
# Out:
# Income [58138. 46344. 71613. ... 56981. 69245. 52869.]
#
# Kidhome [0 1 2]
#
# Teenhome [0 1 2]
#
# Recency [58 38 26 94 16 34 32 19 68 59 82 53 23 51 20 91 86 41 42 63  0 69 89  4
#  96 56 31  8 55 37 76 99  3 88 72 24 92 39 29  2 54 57 30 12 18 75 90  1
#  40  9 87  5 95 48 70 79 84 44 43 35 15 17 46 27 25 74 85 65 13 83 10 21
#  61 73 47 36 49 28 64 78 77 81 80 45 14 52 98 93 50 60 11 66 97 62  6 33
#  22 71 67  7]
#
# MntWines [ 635   11  426  173  520  235   76   14   28    6  194  233    3 1006
#    53   84 1012    4   86    1  867  384  270   36  684    8  112  110
#    96  482   40  702   55  437  421   13    9  123  826  245  650   12
#   510  328  984  295  447  712  452  523  546  398   10  688  247  856
#   496  258  565    2  721 1032  577   64   25  163   17  130  292  350
#   135   15   27    5  505   51  207   41  386  562  217  144  454  425
#  1332  527  490  378  547   47  320   34  722  162  450   70  492  120
# ...

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %%
df.shape
# Out:
# (2205, 37)

# %%
df['AcceptedCmp1'].value_counts()
# Out:
# 0    2063
# 1     142
# Name: AcceptedCmp1, dtype: int64

# %%
plt.figure(figsize=(30,35))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
for i in df.columns:
    sns.kdeplot(df[i], shade = True)
    plt.show()

# %%
# sns.pairplot(df, hue = 'Response')

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ##### Analysing the distribution of Income

# %%
sns.distplot(df['Income'], rug = True)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %% [raw]
# Average income lies at ~51000 and the maximum income is ~113000

# %% [markdown]
# ##### Analysing the distribution of Age

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
df['Age'].describe()
# Out:
# count    2205.000000
# mean       51.095692
# std        11.705801
# min        24.000000
# 25%        43.000000
# 50%        50.000000
# 75%        61.000000
# max        80.000000
# Name: Age, dtype: float64

# %% [raw]
# Average Age is 50 years and the customers belong to the age group between 24 years and 80 years.

# %% [markdown]
# ##### Analysing the distribution of the amount spent on purchasing Gold

# %%
sns.boxenplot(df['MntGoldProds'])
# Out:
# <AxesSubplot:xlabel='MntGoldProds'>

# %%
df['MntGoldProds'].describe()
# Out:
# count    2205.000000
# mean       44.057143
# std        51.736211
# min         0.000000
# 25%         9.000000
# 50%        25.000000
# 75%        56.000000
# max       321.000000
# Name: MntGoldProds, dtype: float64

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# ##### Analysing the relationship between the number of Kids in a family and Response

# %%
pd.crosstab(df['Kidhome'], df['Response']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Kidhome'>

# %% [raw]
# Families having no kids are more inclined to particiapte in the campaigns and make use of the exclusive offers.

# %% [markdown]
# ##### Analysing the relationship between the number of Teens in a family and Response

# %%
pd.crosstab(df['Teenhome'], df['Response'])
# Out:
# Response    0    1
# Teenhome
# 0         903  236
# 1         923   92
# 2          46    5

# %% [raw]
# Similar to families with kids, families with no teenage children are more likely to make use of the offers

# %% [markdown]
# ##### Analysing the relationship between Family Income and Response

# %%
sns.boxenplot(df['Response'], df['Income'], data=df)
# Out:
# <AxesSubplot:xlabel='Response', ylabel='Income'>

# %% [raw]
# Families earning a higher income are keen to save more and hence participate in the promotional campaigns for discounts.

# %% [markdown]
# ##### Analysing the relationship between Family Income and total amt. spent during the last two years

# %%
sns.jointplot(df['Income'],df['MntTotal'], data=df, kind='kde')

# %% [raw]
# A linear relationship can be observed in the above plot. With a rise in disposible income, there is higher propensity to spend.

# %% [markdown]
# ### Model Building

# %%
X = df.drop('Response', axis=1)
y = df['Response']

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,random_state = 10, test_size = 0.2)

# %%
Xtrain.shape,ytrain.shape
# Out:
# ((1764, 36), (1764,))

# %%
Xtest.shape,ytest.shape
# Out:
# ((441, 36), (441,))

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(Xtrain,ytrain)       
y_pred = LR.predict(Xtest)

# %%
pip install imblearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.combine import SMOTETomek

from collections import Counter

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, cohen_kappa_score, f1_score

pnt = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
for i in pnt:
    print('SMOTE = ', i)
    os=SMOTETomek(i)
    X_train_ns,y_train_ns=os.fit_resample(Xtrain,ytrain)
    print("The number of classes before fit {}".format(Counter(ytrain)))
    print("The number of classes after fit {}".format(Counter(y_train_ns)))
          
    classifier= KNeighborsClassifier()
    classifier.fit(X_train_ns, y_train_ns)
    y_pred = classifier.predict(Xtest)
    print('confusion_matrix: ','\n', confusion_matrix(ytest, y_pred))
    print('accuracy_score: ','\n', accuracy_score(ytest, y_pred))
    print('Classification_report :','\n', classification_report(ytest, y_pred))
    print('Cohen Kappa Score :','\n', cohen_kappa_score(ytest,y_pred))
    print('f1_score :','\n', f1_score(ytest, y_pred))
    print('\n')
# Out:
# SMOTE =  0.6
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1438, 1: 838})
# confusion_matrix:
#  [[290  84]
#  [ 37  30]]
# accuracy_score:
#  0.7256235827664399
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       374
#            1       0.26      0.45      0.33        67
#
#     accuracy                           0.73       441
#    macro avg       0.58      0.61      0.58       441
# weighted avg       0.79      0.73      0.75       441
#
# Cohen Kappa Score :
#  0.17327445967929356
# f1_score :
#  0.3314917127071823
#
#
# SMOTE =  0.65
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1421, 1: 896})
# confusion_matrix:
#  [[286  88]
#  [ 33  34]]
# accuracy_score:
#  0.7256235827664399
# Classification_report :
#                precision    recall  f1-score   support
#
# ...

# %%
from imblearn.combine import SMOTETomek

from collections import Counter

from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, cohen_kappa_score, f1_score

pnt = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
for i in pnt:
    print('SMOTE = ', i)
    os=SMOTETomek(i)
    X_train_ns,y_train_ns=os.fit_resample(Xtrain,ytrain)
    print("The number of classes before fit {}".format(Counter(ytrain)))
    print("The number of classes after fit {}".format(Counter(y_train_ns)))
          
    classifier= DecisionTreeClassifier()
    classifier.fit(X_train_ns, y_train_ns)
    y_pred = classifier.predict(Xtest)
    print('confusion_matrix: ','\n', confusion_matrix(ytest, y_pred))
    print('accuracy_score: ','\n', accuracy_score(ytest, y_pred))
    print('Classification_report :','\n', classification_report(ytest, y_pred))
    print('Cohen Kappa Score :','\n', cohen_kappa_score(ytest,y_pred))
    print('f1_score :','\n', f1_score(ytest, y_pred))
    print('\n')
# Out:
# SMOTE =  0.6
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1423, 1: 823})
# confusion_matrix:
#  [[335  39]
#  [ 37  30]]
# accuracy_score:
#  0.8276643990929705
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       374
#            1       0.43      0.45      0.44        67
#
#     accuracy                           0.83       441
#    macro avg       0.67      0.67      0.67       441
# weighted avg       0.83      0.83      0.83       441
#
# Cohen Kappa Score :
#  0.33932584269662924
# f1_score :
#  0.4411764705882353
#
#
# SMOTE =  0.65
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1424, 1: 899})
# confusion_matrix:
#  [[335  39]
#  [ 40  27]]
# accuracy_score:
#  0.8208616780045351
# Classification_report :
#                precision    recall  f1-score   support
#
# ...

# %%
from imblearn.combine import SMOTETomek

from collections import Counter

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, cohen_kappa_score, f1_score

pnt = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
for i in pnt:
    print('SMOTE = ', i)
    os=SMOTETomek(i)
    X_train_ns,y_train_ns=os.fit_resample(Xtrain,ytrain)
    print("The number of classes before fit {}".format(Counter(ytrain)))
    print("The number of classes after fit {}".format(Counter(y_train_ns)))
    
    classifier= RandomForestClassifier()
    classifier.fit(X_train_ns, y_train_ns)
    y_pred = classifier.predict(Xtest)
    print('confusion_matrix: ','\n', confusion_matrix(ytest, y_pred))
    print('accuracy_score: ','\n', accuracy_score(ytest, y_pred))
    print('Classification_report :','\n', classification_report(ytest, y_pred))
    print('Cohen Kappa Score :','\n', cohen_kappa_score(ytest,y_pred))
    print('f1_score :','\n', f1_score(ytest, y_pred))
    print('\n')
# Out:
# SMOTE =  0.6
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1435, 1: 835})
# confusion_matrix:
#  [[353  21]
#  [ 37  30]]
# accuracy_score:
#  0.8684807256235828
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       374
#            1       0.59      0.45      0.51        67
#
#     accuracy                           0.87       441
#    macro avg       0.75      0.70      0.72       441
# weighted avg       0.86      0.87      0.86       441
#
# Cohen Kappa Score :
#  0.4341651181311388
# f1_score :
#  0.5084745762711865
#
#
# SMOTE =  0.65
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1427, 1: 902})
# confusion_matrix:
#  [[355  19]
#  [ 41  26]]
# accuracy_score:
#  0.8639455782312925
# Classification_report :
#                precision    recall  f1-score   support
#
# ...

# %%
from imblearn.combine import SMOTETomek

from collections import Counter

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, cohen_kappa_score, f1_score

pnt = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
for i in pnt:
    print('SMOTE = ', i)
    os=SMOTETomek(i)
    X_train_ns,y_train_ns=os.fit_resample(Xtrain,ytrain)
    print("The number of classes before fit {}".format(Counter(ytrain)))
    print("The number of classes after fit {}".format(Counter(y_train_ns)))
    
    classifier= GradientBoostingClassifier()
    classifier.fit(X_train_ns, y_train_ns)
    y_pred = classifier.predict(Xtest)
    print('confusion_matrix: ','\n', confusion_matrix(ytest, y_pred))
    print('accuracy_score: ','\n', accuracy_score(ytest, y_pred))
    print('Classification_report :','\n', classification_report(ytest, y_pred))
    print('Cohen Kappa Score :','\n', cohen_kappa_score(ytest,y_pred))
    print('f1_score :','\n', f1_score(ytest, y_pred))
    print('\n')
# Out:
# SMOTE =  0.6
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1419, 1: 819})
# confusion_matrix:
#  [[345  29]
#  [ 38  29]]
# accuracy_score:
#  0.8480725623582767
# Classification_report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       374
#            1       0.50      0.43      0.46        67
#
#     accuracy                           0.85       441
#    macro avg       0.70      0.68      0.69       441
# weighted avg       0.84      0.85      0.84       441
#
# Cohen Kappa Score :
#  0.37602686207843217
# f1_score :
#  0.464
#
#
# SMOTE =  0.65
# The number of classes before fit Counter({0: 1498, 1: 266})
# The number of classes after fit Counter({0: 1429, 1: 904})
# confusion_matrix:
#  [[350  24]
#  [ 36  31]]
# accuracy_score:
#  0.8639455782312925
# Classification_report :
#                precision    recall  f1-score   support
#
# ...
